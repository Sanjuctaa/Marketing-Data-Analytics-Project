# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#read files

df= pd.read_csv(r'C:\Users\sanju\Downloads\marketing_data.csv')
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced   84835.0        0
# 1         1        1961  Graduation         Single   57091.0        0
# 2     10476        1958  Graduation        Married   67267.0        0
# 3      1386        1967  Graduation       Together   32474.0        1
# 4      5371        1989  Graduation         Single   21474.0        1
# ...     ...         ...         ...            ...       ...      ...
# 2235  10142        1976         PhD       Divorced   66476.0        0
# 2236   5263        1977    2n Cycle        Married   31056.0        1
# 2237     22        1976  Graduation       Divorced   46310.0        1
# 2238    528        1978  Graduation        Married   65819.0        0
# 2239   4070        1969         PhD        Married   94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df.shape
# Out:
# (2240, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# ## data cleaning

# %%
#check null values
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
df= df.dropna()

# %%
# check duplicates
print('Duplicate values in the Dataframe: ', df.duplicated().sum())
# Out:
# Duplicate values in the Dataframe:  0

# %%
# change datatypes
df['Dt_Customer']= pd.to_datetime(df['Dt_Customer'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2216 non-null   int64
#  1   Year_Birth           2216 non-null   int64
#  2   Education            2216 non-null   object
#  3   Marital_Status       2216 non-null   object
#  4    Income              2216 non-null   float64
#  5   Kidhome              2216 non-null   int64
#  6   Teenhome             2216 non-null   int64
#  7   Dt_Customer          2216 non-null   datetime64[ns]
#  8   Recency              2216 non-null   int64
#  9   MntWines             2216 non-null   int64
#  10  MntFruits            2216 non-null   int64
#  11  MntMeatProducts      2216 non-null   int64
#  12  MntFishProducts      2216 non-null   int64
#  13  MntSweetProducts     2216 non-null   int64
#  14  MntGoldProds         2216 non-null   int64
# ...

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced   84835.0        0
# 1         1        1961  Graduation         Single   57091.0        0
# 2     10476        1958  Graduation        Married   67267.0        0
# 3      1386        1967  Graduation       Together   32474.0        1
# 4      5371        1989  Graduation         Single   21474.0        1
# ...     ...         ...         ...            ...       ...      ...
# 2235  10142        1976         PhD       Divorced   66476.0        0
# 2236   5263        1977    2n Cycle        Married   31056.0        1
# 2237     22        1976  Graduation       Divorced   46310.0        1
# 2238    528        1978  Graduation        Married   65819.0        0
# 2239   4070        1969         PhD        Married   94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### 1. Which product is performing the best?

# %%
total_sales = df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].sum()
print(total_sales)
print('**'*20)
total_sales.plot(kind= 'barh')
# Out:
# MntWines            676083
# MntFruits            58405
# MntMeatProducts     370063
# MntFishProducts      83405
# MntSweetProducts     59896
# MntGoldProds         97427
# dtype: int64
# ****************************************
# <Axes: >

# %% [markdown]
# Insights: Wines are best performing product.

# %% [markdown]
# ### 2. which channels are underperforming?

# %%
frequency_of_use = df[['NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].mean()
print("Frequency of Use by Channel:")
print(frequency_of_use)
# Out:
# Frequency of Use by Channel:
# NumWebPurchases        4.085289
# NumCatalogPurchases    2.671029
# NumStorePurchases      5.800993
# dtype: float64

# %%
frequency_of_use.plot(kind= 'barh')
# Out:
# <Axes: >

# %% [markdown]
# Insights: The most underperforming channel is the catalog channel.

# %% [markdown]
# ### 3. Which factors are significantly responsible for number of web purchases?

# %%
corr_matrix = df.corr()

print(corr_matrix['NumWebPurchases'].sort_values(ascending=False))
# Out:
# NumWebPurchases        1.000000
# MntWines               0.553786
# NumStorePurchases      0.516240
# MntGoldProds           0.407066
#  Income                0.387878
# NumCatalogPurchases    0.386868
# MntSweetProducts       0.333937
# MntMeatProducts        0.307090
# MntFruits              0.302039
# MntFishProducts        0.299688
# NumDealsPurchases      0.241440
# AcceptedCmp4           0.162932
# Teenhome               0.162077
# AcceptedCmp1           0.159292
# Response               0.151431
# AcceptedCmp5           0.141189
# AcceptedCmp3           0.042958
# AcceptedCmp2           0.034829
# Recency               -0.005641
# Complain              -0.016642
# ID                    -0.018476
# NumWebVisitsMonth     -0.051226
# Year_Birth            -0.153051
# Kidhome               -0.371977
# Name: NumWebPurchases, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Select relevant features and target
features = ['Recency', 'NumWebVisitsMonth','Kidhome', 'Teenhome']
target = 'NumWebPurchases'

X = df[features]
y = df[target]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict and evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Get feature importance
feature_importance = pd.Series(model.coef_, index=features)
print('Feature Importance:')
print(feature_importance.sort_values(ascending=False))
# Out:
# Mean Squared Error: 6.528472893250547
# Feature Importance:
# Teenhome             0.824820
# NumWebVisitsMonth    0.140581
# Recency              0.001420
# Kidhome             -2.198674
# dtype: float64

# %%
# Bar plot of feature importance
plt.figure(figsize=(7,4))
feature_importance.sort_values().plot(kind='barh')
plt.title('Feature Importance for Number of Web Purchases')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# Insights: Number of teenagers at home of customers has mainly responsible for number of web purchases.

# %% [markdown]
# ### 4. Which marketing campaigns (AcceptedCmp1, AcceptedCmp2, etc.) have the highest acceptance rates?

# %%
# Calculate acceptance rates for each campaign
acceptance_rates = {
    'Campaign 1': df['AcceptedCmp1'].mean() * 100,
    'Campaign 2': df['AcceptedCmp2'].mean() * 100,
    'Campaign 3': df['AcceptedCmp3'].mean() * 100,
    'Campaign 4': df['AcceptedCmp4'].mean() * 100,
    'Campaign 5': df['AcceptedCmp5'].mean() * 100,
}

print("Acceptance Rates for Each Campaign:")
print(acceptance_rates)
# Out:
# Acceptance Rates for Each Campaign:
# {'Campaign 1': 6.407942238267148, 'Campaign 2': 1.3537906137184115, 'Campaign 3': 7.355595667870037, 'Campaign 4': 7.400722021660649, 'Campaign 5': 7.310469314079422}

# %% [markdown]
# Campaign 4 has the highest acceptance rate .

# %% [markdown]
# ### 5. What proportion of customers have lodged a complaint in the last 2 years?

# %%
num_complaints = df['Complain'].sum()

# Calculate the total number of customers
total_customers = df.shape[0]

# Calculate the proportion of customers who have lodged a complaint
proportion_complaints = num_complaints / total_customers

# Print the results
print(f"Number of customers who have lodged a complaint: {num_complaints}")
print(f"Total number of customers: {total_customers}")
print(f"Proportion of customers who have lodged a complaint: {proportion_complaints:.2%}")
# Out:
# Number of customers who have lodged a complaint: 21
# Total number of customers: 2216
# Proportion of customers who have lodged a complaint: 0.95%

# %%
complain= df['Complain'].value_counts()
plt.pie(complain, labels= complain.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Insights: Out of 2216 customers only 21 customers which is 0.95% have lodged complains over two years.

# %% [markdown]
# ### 6. Which country has the highest average spending on gold products?

# %%
# Group by country and calculate the average spending on gold products
average_spending_by_country = df.groupby('Country')['MntGoldProds'].mean()

# Identify the country with the highest average spending on gold products
print(average_spending_by_country.sort_values())
# Out:
# Country
# India           40.911565
# Spain           42.251601
# Saudi Arabia    44.893175
# USA             45.224299
# Canada          45.654135
# Australia       48.517007
# Germany         49.724138
# Mexico          73.333333
# Name: MntGoldProds, dtype: float64

# %% [markdown]
# Mexico has the highest average spending on gold products.
